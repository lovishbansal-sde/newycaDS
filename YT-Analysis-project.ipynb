# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyBfwQfMcFWVFIztDAr6qpAJ8KmImWFyJPw'
#channel_id = 'UCnz-ZXXER4jOvuED5trXfEA'
channel_ids = ['UCnz-ZXXER4jOvuED5trXfEA', # techTFQ
               'UCLLw7jmFsvfIVaUFsLs8mlQ', # Luke Barousse 
               'UCiT9RITQ9PW6BhXK0y2jaeg', # Ken Jee
               'UC7cs8q-gJRlGwj4A8OmCmXg', # Alex the analyst
               'UC2UXDak6o7rBm23k3Vv5dww' # Tina Huang
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#        Channel_name Subscribers     Views Total_videos  \
# 0     Luke Barousse      279000  12188282           89
# 1        Tina Huang      425000  17287224          111
# 2  Alex The Analyst      325000  12796243          180
# 3           Ken Jee      227000   7248146          242
# 4           techTFQ      141000   6714961           80
#
#                 playlist_id
# 0  UULLw7jmFsvfIVaUFsLs8mlQ
# 1  UU2UXDak6o7rBm23k3Vv5dww
# 2  UU7cs8q-gJRlGwj4A8OmCmXg
# 3  UUiT9RITQ9PW6BhXK0y2jaeg
# 4  UUnz-ZXXER4jOvuED5trXfEA

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# ## Function to get video ids

# %%
channel_data
# Out:
#        Channel_name  Subscribers     Views  Total_videos  \
# 0  Alex The Analyst       325000  12796243           180
# 1     Luke Barousse       279000  12188282            89
# 2        Tina Huang       425000  17287224           111
# 3           Ken Jee       227000   7248146           242
# 4           techTFQ       141000   6714961            80
#
#                 playlist_id
# 0  UU7cs8q-gJRlGwj4A8OmCmXg
# 1  UULLw7jmFsvfIVaUFsLs8mlQ
# 2  UU2UXDak6o7rBm23k3Vv5dww
# 3  UUiT9RITQ9PW6BhXK0y2jaeg
# 4  UUnz-ZXXER4jOvuED5trXfEA

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Ken Jee', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['oNvyvYGw5n4',
#  'GaZRuchRCyw',
#  'EBjYqC3aNTA',
#  'QMP858aZcow',
#  '0ItYIoOrrUs',
#  'KzTFoUbThvM',
#  'bBJd0oPdNak',
#  'Yk-unX4KnV4',
#  'z0_xrtFdFj8',
#  'vVpkXEIn-q0',
#  'aipz4p7GDL4',
#  'iPdO9MwdcLE',
#  'YPph59-rTxA',
#  '-2U2CMYom00',
#  'KEeUR8UDy-s',
#  '0jTtHYie3CU',
#  '2RWwN5ZT4tA',
#  'rEWPqw6rMGI',
#  'o-wsyxWbPOw',
#  'xpIFS6jZbe8',
#  '-zbLpoJVBMI',
#  'scSc6YSanQ0',
#  'FqNpDNmpcEo',
#  'vwvdtXMcNzI',
#  '2qVWurPFwfc',
#  '35g8fCi-kbw',
#  'n6MiRgxN5iA',
#  'ammCGdzSoag',
#  '15c7WD-lKUY',
#  'TjGFBQC27ng',
#  'qUK5Vk4NvBw',
#  'cnqTU6eJwH0',
#  'k8YxyrcAXJs',
#  'VvnOXDCVm8k',
#  '68GGPK3WaqI',
#  'S4Lei5mOppc',
#  'tG_UW_p0UqE',
#  '143WWA5Sy9k',
#  's1gD35Z4eUc',
#  'nrEJGGxcoTc',
#  'KfpOuSH9gDc',
#  'sICJ6a2wX5g',
#  'iiSZqsQKNX8',
#  'IoUWD1h6xUs',
#  '7JCterBrcvk',
#  'KU__lDJj5iU',
#  '8nTmuKI2oyA',
#  'SaWxVk7rDp4',
#  'n7kjelw9s2w',
#  '8Pi36Nj6P9A',
#  'hOUrxTeBJQc',
#  '-ONQ628CXKQ',
#  'sHRq-LshG3U',
#  'EMq4PH7PCeA',
#  'BlSrorP32WM',
#  'pPfw2fzwNiM',
#  'hcHSSyHbgMQ',
#  'ITAxTid_1YU',
#  'fU3DOXjwufg',
#  'tJI-1mHeXoA',
#  'SVtRsDhHlDk',
#  'OtqQYqRNDGI',
#  'uic34RTaI-w',
#  'GO420aMtHfk',
#  'KQ80oD_boBM',
#  'r-DR9HBaipU',
#  'qV_AlRwhI3I',
#  '41Clrh6nv1s',
#  'YR9Faf1uZDg',
#  'myhoWUrSP7o',
#  'ji7DtgUeKCI',
#  '4039x4r-hGE',
#  '78LjdAAw0wA',
#  'yUrrf3Pm33s',
#  'domVw8isGOI',
#  '_0rHU6qAQe0',
#  'tnpV1etgcxs',
#  'Uf0dO-pgOrk',
#  'N97MhZEp2UQ',
#  '1Ir1NgCuI0Y',
#  'd6FeV8WXPWY',
#  'WRF_dKZ_i24',
#  'UpaEjBOMNqs',
#  'UKuK2fXu_dU',
#  'Ft4GVkQQtgk',
#  'BBDiadC8BvE',
#  '7VcdvSyoxnc',
#  '8Vxjp2KVHqs',
#  'Kq9dkZu0bpg',
#  'omdhf8d53FM',
#  'apf6A3Nstm8',
#  'jf3j0lWmFPU',
#  'g7on3Rw0Ovg',
#  'rLawTH--l2Y',
#  '-pdXWmj9xxU',
#  'vfV4nm004VQ',
#  'oHUD2T_VXfI',
#  'uXLnbdHMf8w',
#  '5v_ulmGv-gc',
#  'q6Lf2yhvluw',
#  'iGUiLWFDWfk',
#  'SsGKZe4dVyk',
#  'RAMxzqSMDKE',
#  'YbTMIxjk4hI',
#  'S_CuB__nsmI',
#  'KEBVcVwFzaI',
#  'vQGJvmhpq_s',
#  'Xgg7dIKys9E',
#  'UuR3nomI5AE',
#  '6tQtwqthUMI',
#  'QN3wXPZSjpE',
#  'rdo8YBasqqA',
#  '_rbrdNTpZGo',
#  'ELFGsNqZrlM',
#  'PWmxLYTixAM',
#  'I3FBJdiExcg',
#  'hO_YKK_0Qck',
#  '2KkrtG5IsHo',
#  'QQLToUlgN7A',
#  '6aaIbd-GpZs',
#  'lsXWVPzwZPk',
#  'AqPquogHwq0',
#  '742LQ38OioU',
#  'B1g_yMKpdwo',
#  'zGlJ-QndG8E',
#  '6fwyyRgZlD0',
#  '-3d1NctSv0c',
#  'WnB1jsDu900',
#  'XjC3FPL-S78',
#  'txR8_jGi0Ls',
#  '4qZINLzwYyk',
#  'mR2NCRgtLPE',
#  'mEZ1Hj5yQ-8',
#  'HJH0gfY6EUg',
#  'BZFfNwj7JhE',
#  '_K6cNdgN3CI',
#  '1aXk2RViq3c',
#  'UcilY6HDuL8',
#  'jam0xApfC-U',
#  '4OZip0cgOho',
#  'QBIe4nbmZfA',
#  'KHAuuOQui2U',
#  'DW55gaQ_Egk',
#  'lUUqrRgerd8',
#  'ei1m5lDQyBg',
#  '9D7GzskcyUk',
#  'agHKuUoMwvY',
#  'nUOh_lDMHOU',
#  '7O4dpR9QMIM',
#  'QWgg4w1SpJ8',
#  'fhi4dOhmW-g',
#  'GmW4F6MHqqs',
#  'MpF9HENQjDo',
#  '9ZwVqXUHf6o',
#  'a3VWq9smqhM',
#  'oMdVg6GPODA',
#  'vy-R4oUZaC8',
#  'XGBigjVy2Eo',
#  'hpMc6TgT34I',
#  'Fs_LG5Y8GIU',
#  'Ip50cXvpWY4',
#  'imMPnCHvbkY',
#  '3bes4U4MHPg',
#  'qP0hRF-lGqg',
#  'aaAZXeuPIXk',
#  'C4OPn58BLaU',
#  '8igH8qZafpo',
#  'xjhW1rSQeik',
#  'DM1eE_Coh6g',
#  'f6NPw582FFc',
#  'dlZWB2D-NaQ',
#  'foggudmDDvY',
#  'n3vw0M5RrPU',
#  '2OnXytYziF0',
#  'Q9FjwzKFPuM',
#  'VN12ZPFsApM',
#  'WKXtTo7lqmA',
#  '9-2OKLZfvbE',
#  '3TrAYmrmA8o',
#  '5SjK6YCs4o4',
#  'iqG59TqfFdY',
#  'NCyPY-jfb3I',
#  'DopikusDfk0',
#  'm5pwx3hgtzM',
#  '74Z3F7i4qcI',
#  'zSwM5uVeylU',
#  'BXmEmIK5aqI',
#  'SLC5sPZSLY4',
#  'EAezvs0eL1s',
#  'k4r_NtB4JVQ',
#  'ZWdyBbgGZBQ',
#  '1FrY7ARSf10',
#  'LGEuDWjWQes',
#  'fjVVtvp5X0w',
#  '-kX2b6TF_9k',
#  '3ysXGYjvbSU',
#  'akbU9KOo_Qc',
#  '3BEtGaz70rQ',
#  'RRXWJVX0fE8',
#  'k-gin1qfzi0',
#  'Zz_Mx1UPswI',
#  '3Mm1U1CbzNw',
#  '4yI3vVe0Jos',
#  'pWVQ0vN5uig',
#  'a-Syoa9mPhM',
#  'yukdXV9LR48',
#  'XWetgrNas-k',
#  'yIJrCFXs0rU',
#  'Z9dGmL2G-4k',
#  'T7BQJJIGrmc',
#  'T77uVbLhroQ',
#  '1Cf7SdnBncg',
#  '3cDM9Z-fdz4',
#  'Yr5T3T4tq-g',
#  'KMOA5arCi8g',
#  'Z_KFh-HqaBA',
#  '5jntoZX-Tc8',
#  'AxP1CL0yaFQ',
#  'zF_Q2v_9zKY',
#  '4CpmB4TR2C4',
#  '6sJEnzDjJqI',
#  '1UjMBw_7Gi8',
#  'q8cEt8gj3zY',
#  '_CS4u9cORwA',
#  'XTrlMQXYqts',
#  'smeFkHwnM_k',
#  'sq5TnVJWv6A',
#  'XoUyK3XHZHs',
#  'tv1e22u2COk',
#  'j-Z-je6K4Yg',
#  'sCOX5yShmFA',
#  'FBgs-BSTIJE',
#  'irjTWNV0eAY',
#  'RRSRKf9eQxc',
#  'IFceyuL6GZY',
#  'Y_SMU701qlA',
#  'qfRhKHV8-t4']

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                            #    Dislikes = video['statistics']['dislikeCount'],
                               Comments = video['statistics']['commentCount']
                               )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
# video_data['Dislikes'] = pd.to_numeric(video_data['Dislikes'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0                     State of Data Science - Web Data     2022-08-05   8086
# 1       Data Science Town Hall - State of Data Science     2022-08-04   8568
# 2    How I Would Learn to Code (If I Had to Start O...     2022-07-29   7007
# 3    5 Impactful Data Science Projects For Your Por...     2022-06-27  23157
# 4          Can Machine Learning Fix My Baseball Swing?     2022-06-10   6303
# ..                                                 ...            ...    ...
# 232                How to Simulate NBA Games in Python     2018-11-19  15555
# 233          Should You Get A Masters in Data Science?     2018-11-14  19770
# 234  How I Became A Data Scientist From a Business ...     2018-11-12   6066
# 235  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   7777
# 236  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  17837
#
#      Likes Comments
# 0      317       29
# 1      349       38
# 2      435       49
# 3     1264       84
# 4      307       68
# ..     ...      ...
# 232    353       54
# 233    294      141
# 234    187       23
# 235    176       17
# 236    270       41
#
# [237 rows x 5 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title Published_date  \
# 139  How I Would Learn Data Science (If I Had to St...     2020-05-08
# 160  The Best Free Data Science Courses Nobody is T...     2020-03-09
# 166  3 Proven Data Science Projects for Beginners (...     2020-02-17
# 19   How I Would Learn Data Science in 2022 (If I H...     2021-12-27
# 115  Beginner Kaggle Data Science Project Walk-Thro...     2020-07-17
# 205  The Projects You Should Do To Get A Data Scien...     2019-07-30
# 67   How I Would Learn Data Science in 2021 (What H...     2020-12-19
# 152  Data Science Project from Scratch - Part 1 (Pr...     2020-04-03
# 52      Why You Probably Won't Become a Data Scientist     2021-04-09
# 174  Data Science Certificate vs Bootcamp vs Master...     2020-01-18
#
#        Views  Likes Comments
# 139  1352195  48041     1990
# 160   324927  20316      612
# 166   287416  16383      509
# 19    265938  12103      467
# 115   232379   5594      388
# 205   141338   5475      251
# 67    128869   5923      505
# 152   128176   3722      161
# 52    123135   3591      475
# 174   102567   2904      577

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)

# %%
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0                     State of Data Science - Web Data     2022-08-05   8086
# 1       Data Science Town Hall - State of Data Science     2022-08-04   8568
# 2    How I Would Learn to Code (If I Had to Start O...     2022-07-29   7007
# 3    5 Impactful Data Science Projects For Your Por...     2022-06-27  23157
# 4          Can Machine Learning Fix My Baseball Swing?     2022-06-10   6303
# ..                                                 ...            ...    ...
# 232                How to Simulate NBA Games in Python     2018-11-19  15555
# 233          Should You Get A Masters in Data Science?     2018-11-14  19770
# 234  How I Became A Data Scientist From a Business ...     2018-11-12   6066
# 235  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   7777
# 236  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  17837
#
#      Likes Comments
# 0      317       29
# 1      349       38
# 2      435       49
# 3     1264       84
# 4      307       68
# ..     ...      ...
# 232    353       54
# 233    294      141
# 234    187       23
# 235    176       17
# 236    270       41
#
# [237 rows x 5 columns]

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0                     State of Data Science - Web Data     2022-08-05   8086
# 1       Data Science Town Hall - State of Data Science     2022-08-04   8568
# 2    How I Would Learn to Code (If I Had to Start O...     2022-07-29   7007
# 3    5 Impactful Data Science Projects For Your Por...     2022-06-27  23157
# 4          Can Machine Learning Fix My Baseball Swing?     2022-06-10   6303
# ..                                                 ...            ...    ...
# 232                How to Simulate NBA Games in Python     2018-11-19  15555
# 233          Should You Get A Masters in Data Science?     2018-11-14  19770
# 234  How I Became A Data Scientist From a Business ...     2018-11-12   6066
# 235  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   7777
# 236  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  17837
#
#      Likes Comments Month
# 0      317       29   Aug
# 1      349       38   Aug
# 2      435       49   Jul
# 3     1264       84   Jun
# 4      307       68   Jun
# ..     ...      ...   ...
# 232    353       54   Nov
# 233    294      141   Nov
# 234    187       23   Nov
# 235    176       17   Jul
# 236    270       41   Nov
#
# [237 rows x 6 columns]

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    20
# 1    Aug    23
# 2    Dec    19
# 3    Feb    15
# 4    Jan    21
# 5    Jul    25
# 6    Jun    19
# 7    Mar    22
# 8    May    21
# 9    Nov    19
# 10   Oct    16
# 11   Sep    17

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
             'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
video_data.to_csv('Video_Details(Ken Jee).csv')
